# %% [markdown]
# <a href="https://colab.research.google.com/github/Codebyjanhvi/Bilateral-Debt/blob/main/IDCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# Load your Excel file
raw = pd.read_excel("IDS_ALLCountries.xlsx", sheet_name="Data", engine='openpyxl')  # adjust sheet name and specify engine
raw.head()
# Out:
#   Country Name Country Code Counterpart-Area Name Counterpart-Area Code  \
# 0  Afghanistan          AFG                 World                   WLD
# 1  Afghanistan          AFG                 World                   WLD
# 2  Afghanistan          AFG                 World                   WLD
# 3  Afghanistan          AFG                 World                   WLD
# 4  Afghanistan          AFG                 World                   WLD
#
#                                          Series Name  Series Code  1970  1971  \
# 0  Average grace period on new external debt comm...  DT.GPA.DPPG   NaN   NaN
# 1  Average grace period on new external debt comm...  DT.GPA.OFFT   NaN   NaN
# 2  Average grace period on new external debt comm...  DT.GPA.PRVT   NaN   NaN
# 3  Average grant element on new external debt com...  DT.GRE.DPPG   NaN   NaN
# 4  Average grant element on new external debt com...  DT.GRE.OFFT   NaN   NaN
#
#    1972  1973  ...  2022  2023  2024  2025  2026  2027  2028  2029  2030  2031
# 0   NaN   NaN  ...   0.0   0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN  ...   0.0   0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN  ...   0.0   0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN  ...   0.0   0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN  ...   0.0   0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 68 columns]

# %%
# Get all numeric year columns (they should be strings like "1970", "1971")
year_cols = [col for col in raw.columns if str(col).isdigit()]
print(year_cols[:5])  # should show ['1970','1971','1972',...]
# Out:
# [1970, 1971, 1972, 1973, 1974]

# %%
long = raw.melt(
    id_vars=["Country Name", "Country Code", "Series Name", "Series Code"],
    value_vars=year_cols,
    var_name="Year",
    value_name="Value"
)

# Convert Year to int
long["Year"] = long["Year"].astype(int)
long
# Out:
#                                               Country Name Country Code  \
# 0                                              Afghanistan          AFG
# 1                                              Afghanistan          AFG
# 2                                              Afghanistan          AFG
# 3                                              Afghanistan          AFG
# 4                                              Afghanistan          AFG
# ...                                                    ...          ...
# 4769097                                                NaN          NaN
# 4769098                                                NaN          NaN
# 4769099                                                NaN          NaN
# 4769100  Data from database: International Debt Statistics          NaN
# 4769101                           Last Updated: 02/26/2025          NaN
#
#                                                Series Name  Series Code  Year  \
# 0        Average grace period on new external debt comm...  DT.GPA.DPPG  1970
# 1        Average grace period on new external debt comm...  DT.GPA.OFFT  1970
# 2        Average grace period on new external debt comm...  DT.GPA.PRVT  1970
# 3        Average grant element on new external debt com...  DT.GRE.DPPG  1970
# 4        Average grant element on new external debt com...  DT.GRE.OFFT  1970
# ...                                                    ...          ...   ...
# 4769097                                                NaN          NaN  2031
# 4769098                                                NaN          NaN  2031
# 4769099                                                NaN          NaN  2031
# 4769100                                                NaN          NaN  2031
# 4769101                                                NaN          NaN  2031
#
#          Value
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 4769097    NaN
# 4769098    NaN
# 4769099    NaN
# 4769100    NaN
# 4769101    NaN
#
# [4769102 rows x 6 columns]

# %%
long = long.dropna(subset=["Value"])
long.to_csv("ids_clean_long.csv", index=False)

# %%
meta = pd.read_excel("IDS_ALLCountries.xlsx", sheet_name="Country - Metadata")  # adjust name if needed
meta.head()
# Out:
#   Code                                Long Name         Income Group  \
# 0  AFG             Islamic State of Afghanistan           Low income
# 1  ALB                      Republic of Albania  Upper middle income
# 2  DZA  People's Democratic Republic of Algeria  Upper middle income
# 3  AGO              People's Republic of Angola  Lower middle income
# 4  ARG                       Argentine Republic  Upper middle income
#
#                        Region Lending category Other groups   Currency Unit  \
# 0                  South Asia              IDA         HIPC  Afghan afghani
# 1       Europe & Central Asia             IBRD          NaN    Albanian lek
# 2  Middle East & North Africa             IBRD          NaN  Algerian dinar
# 3          Sub-Saharan Africa             IBRD          NaN  Angolan kwanza
# 4   Latin America & Caribbean             IBRD          NaN  Argentine peso
#
#   Latest population census                     Latest household survey  \
# 0                     1979         Demographic and Health Survey, 2015
# 1          2020 (expected)      Demographic and Health Survey, 2017/18
# 2          2020 (expected)  Multiple Indicator Cluster Survey, 2018/19
# 3                     2014      Demographic and Health Survey, 2015/16
# 4          2020 (expected)  Multiple Indicator Cluster Survey, 2019/20
#
#                                        Special Notes  ...  \
# 0  The reporting period for national accounts dat...  ...
# 1                                                NaN  ...
# 2                                                NaN  ...
# 3  The World Bank systematically assesses the app...  ...
# 4  The World Bank systematically assesses the app...  ...
#
#    Source of most recent Income and expenditure data  \
# 0         Integrated household survey (IHS), 2016/17
# 1  Living Standards Measurement Study Survey (LSM...
# 2            Integrated household survey (IHS), 2011
# 3         Integrated household survey (IHS), 2008/09
# 4            Integrated household survey (IHS), 2016
#
#    Vital registration complete Latest agricultural census  \
# 0                          NaN                        NaN
# 1                          Yes                       2012
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          Yes                       2008
#
#   Latest industrial data Latest trade data Latest water withdrawal data  \
# 0                    NaN            2018.0                       2000.0
# 1                 2013.0            2018.0                       2006.0
# 2                 2010.0            2017.0                       2012.0
# 3                    NaN            2018.0                       2005.0
# 4                 2002.0            2018.0                       2011.0
#
#   2-alpha code WB-2 code   Table Name   Short Name
# 0           AF        AF  Afghanistan  Afghanistan
# 1           AL        AL      Albania      Albania
# 2           DZ        DZ      Algeria      Algeria
# 3           AO        AO       Angola       Angola
# 4           AR        AR    Argentina    Argentina
#
# [5 rows x 30 columns]

# %%
long = long.merge(
    meta[["Code", "Region", "Income Group"]],
    left_on="Country Code",
    right_on="Code",
    how="left"
)

# %%
long = long[long["Region"].notna()]
long = long[~long["Region"].str.contains("Aggregates", case=False)]

# %%
print(long["Country Name"].nunique(), "countries remain")
print(long["Country Name"].unique()[:20])
# Out:
# 120 countries remain
# ['Albania' 'Algeria' 'Angola' 'Argentina' 'Armenia' 'Azerbaijan'
#  'Bangladesh' 'Belarus' 'Belize' 'Benin' 'Bhutan' 'Bolivia'
#  'Bosnia and Herzegovina' 'Botswana' 'Brazil' 'Burkina Faso' 'Burundi'
#  'Cabo Verde' 'Cambodia' 'Cameroon']

# %%
long.to_csv("ids_clean_long_filtered.csv", index=False)

# %%
series_map = {
    "ext_debt_usd": "DT.DOD.DECT.CD",
    "debt_service_usd": "DT.TDS.DECT.CD",
    "gni_usd": "NY.GNP.MKTP.CD",
    "population": "SP.POP.TOTL"
}

long_key = long[long["Series Code"].isin(series_map.values())].copy()

# %%
wide = long_key.pivot_table(
    index=["Country Name", "Country Code", "Region", "Income Group", "Year"],
    columns="Series Code",
    values="Value",
    aggfunc="first"
).reset_index()

# Rename columns to friendly names
wide = wide.rename(columns={v: k for k, v in series_map.items()})
wide.head()
# Out:
# Series Code Country Name Country Code      Region Income Group  Year  \
# 0            Afghanistan          AFG  South Asia   Low income  2006
# 1            Afghanistan          AFG  South Asia   Low income  2007
# 2            Afghanistan          AFG  South Asia   Low income  2008
# 3            Afghanistan          AFG  South Asia   Low income  2009
# 4            Afghanistan          AFG  South Asia   Low income  2010
#
# Series Code  ext_debt_usd  debt_service_usd       gni_usd  population
# 0            9.793445e+08        10894252.3  7.100374e+09  25424094.0
# 1            2.023035e+09         6154687.8  9.877773e+09  25909852.0
# 2            2.143952e+09         8030776.5  1.010720e+10  26482622.0
# 3            2.480214e+09        10739033.8  1.237834e+10  27466101.0
# 4            2.435845e+09        10431611.1  1.588578e+10  28284089.0

# %%
wide["debt_per_capita_usd"] = wide["ext_debt_usd"] / wide["population"]
wide["debt_pct_gni"] = (wide["ext_debt_usd"] / wide["gni_usd"]) * 100
wide["debt_service_pct_gni"] = (wide["debt_service_usd"] / wide["gni_usd"]) * 100

# %%
wide = wide.sort_values(["Country Code","Year"])

# CAGR 2013-2023 per country
def compute_cagr(sub, col, start=2013, end=2023):
    start_val = sub.loc[sub["Year"] == start, col]
    end_val   = sub.loc[sub["Year"] == end, col]
    if len(start_val)==0 or len(end_val)==0 or start_val.iloc[0]<=0 or end_val.iloc[0]<=0:
        return None
    n = end - start
    return (end_val.iloc[0] / start_val.iloc[0]) ** (1/n) - 1

cagr_list = []
for ccode, g in wide.groupby("Country Code"):
    cagr_list.append({
        "Country Code": ccode,
        "debt_cagr_2013_2023": compute_cagr(g, "ext_debt_usd"),
        "gni_cagr_2013_2023": compute_cagr(g, "gni_usd")
    })

cagr_df = pd.DataFrame(cagr_list)
wide = wide.merge(cagr_df, on="Country Code", how="left")

# YoY growth in debt service burden
wide["ds_burden_yoy"] = wide.groupby("Country Code")["debt_service_pct_gni"].pct_change()
# Out:
# /tmp/ipython-input-953230405.py:24: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   wide["ds_burden_yoy"] = wide.groupby("Country Code")["debt_service_pct_gni"].pct_change()

# %%
wide.to_csv("vw_country_year_summary.csv", index=False)
